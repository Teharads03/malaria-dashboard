# %%
import pandas as pd

df = pd.read_csv("malaria_indicators_lka.csv")

# %% [markdown]
# Display Dataset

# %%
df.head()
# Out:
#               GHO (CODE)                                      GHO (DISPLAY)  \
# 0        #indicator+code                                    #indicator+name
# 1      MALARIA_MICR_TEST  Number of malaria suspects examined by microscopy
# 2       MALARIA_PF_INDIG   Number of indigenous P. falciparum malaria cases
# 3        MALARIA_RDT_POS  Number of malaria positive cases by rapid diag...
# 4  MALARIA_EST_INCIDENCE  Estimated malaria incidence (per 1000 populati...
#
#                                            GHO (URL) YEAR (DISPLAY)  \
# 0                                     #indicator+url     #date+year
# 1  https://www.who.int/data/gho/data/indicators/i...           2021
# 2  https://www.who.int/data/gho/data/indicators/i...           2022
# 3  https://www.who.int/data/gho/data/indicators/i...           2016
# 4  https://www.who.int/data/gho/data/indicators/i...           2022
#
#           STARTYEAR         ENDYEAR REGION (CODE) REGION (DISPLAY)  \
# 0  #date+year+start  #date+year+end  #region+code     #region+name
# 1              2021            2021          SEAR  South-East Asia
# 2              2022            2022          SEAR  South-East Asia
# 3              2016            2016          SEAR  South-East Asia
# 4              2022            2022          SEAR  South-East Asia
#
#   COUNTRY (CODE) COUNTRY (DISPLAY) DIMENSION (TYPE) DIMENSION (CODE)  \
# 0  #country+code     #country+name  #dimension+type  #dimension+code
# 1            LKA         Sri Lanka              NaN              NaN
# 2            LKA         Sri Lanka              NaN              NaN
# 3            LKA         Sri Lanka              NaN              NaN
# 4            LKA         Sri Lanka              NaN              NaN
#
#   DIMENSION (NAME)               Numeric             Value  \
# 0  #dimension+name  #indicator+value+num  #indicator+value
# 1              NaN              673744.0           673 744
# 2              NaN                   0.0                 0
# 3              NaN                   1.0                 1
# 4              NaN                   0.0           0 [0-0]
#
#                     Low                   High
# 0  #indicator+value+low  #indicator+value+high
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   0.0                    0.0

# %% [markdown]
# Drop the first row (metadata)

# %%
df = df.drop(index=0).reset_index(drop=True)

# %%
print(df.columns.tolist())
# Out:
# ['GHO (CODE)', 'GHO (DISPLAY)', 'GHO (URL)', 'YEAR (DISPLAY)', 'STARTYEAR', 'ENDYEAR', 'REGION (CODE)', 'REGION (DISPLAY)', 'COUNTRY (CODE)', 'COUNTRY (DISPLAY)', 'DIMENSION (TYPE)', 'DIMENSION (CODE)', 'DIMENSION (NAME)', 'Numeric', 'Value', 'Low', 'High']

# %% [markdown]
# Rename columns

# %%
df = df.rename(columns={
    'GHO (CODE)': 'indicator_code',
    'GHO (DISPLAY)': 'indicator_name',
    'YEAR (DISPLAY)': 'year',
    'COUNTRY (DISPLAY)': 'country',
    'Numeric': 'numeric_value',
    'Value': 'value'
})

# %% [markdown]
# Drop all other irrelevant columns

# %%
columns_to_keep = ['indicator_code', 'indicator_name', 'year', 'country', 'value']
df = df[columns_to_keep]

# %% [markdown]
# Clean 'value' column (remove spaces, convert to numeric or set NaN)

# %%
df['value'] = df['value'].str.replace(" ", "").str.extract(r"(\d+\.?\d*)")[0]
df['value'] = pd.to_numeric(df['value'], errors='coerce')

# %% [markdown]
# Convert year and numeric columns

# %%
df['year'] = pd.to_numeric(df['year'], errors='coerce')

# %%
df = df.dropna(subset=['year', 'value'])

# %%
print(df.dtypes)
# Out:
# indicator_code     object
# indicator_name     object
# year                int64
# country            object
# value             float64
# dtype: object

# %%
df.head()
# Out:
#           indicator_code                                     indicator_name  \
# 0      MALARIA_MICR_TEST  Number of malaria suspects examined by microscopy
# 1       MALARIA_PF_INDIG   Number of indigenous P. falciparum malaria cases
# 2        MALARIA_RDT_POS  Number of malaria positive cases by rapid diag...
# 3  MALARIA_EST_INCIDENCE  Estimated malaria incidence (per 1000 populati...
# 4  MALARIA_EST_INCIDENCE  Estimated malaria incidence (per 1000 populati...
#
#    year    country     value
# 0  2021  Sri Lanka  673744.0
# 1  2022  Sri Lanka       0.0
# 2  2016  Sri Lanka       1.0
# 3  2022  Sri Lanka       0.0
# 4  2021  Sri Lanka       0.0

# %% [markdown]
# Save Cleaned Dataset

# %%
df.to_csv("cleaned_malaria_data.csv", index=False)
